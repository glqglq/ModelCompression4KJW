# %%
import numpy as np
npyfile = np.load('teacher.npy')

# %%
np.zeros((2,2,2)).reshape(2,4)
# Out:
# array([[0., 0., 0., 0.],
#        [0., 0., 0., 0.]])

# %%
npyfile.item()
# Out:
# {u'cccp1': {'biases': array([-1.6400156e-03, -6.2719160e-03,  1.2537261e-02,  2.4495109e-03,
#           1.6512135e-03,  7.3912146e-04, -9.9479000e-04,  2.1285659e-03,
#          -1.2881629e-03,  1.0421216e-03, -8.9670736e-03, -1.7095563e-03,
#          -9.8499804e-05,  1.1823236e-02,  2.2818659e-04,  1.6910430e-02,
#           3.4097373e-03, -3.6987257e-03,  9.7461641e-03,  7.1185571e-03,
#          -3.0551711e-03,  1.0060653e-03, -3.3099691e-03, -5.2784877e-03,
#           3.9435732e-03,  1.7037194e-03,  1.4418190e-03, -7.6148979e-05,
#           2.7768440e-03, -6.3481933e-04,  4.3488592e-03,  1.1933401e-03,
#           2.6982729e-03, -7.1052662e-03, -6.6257333e-03, -1.2871380e-04,
#          -3.4047390e-04, -2.5057115e-03,  1.5578649e-02, -2.4019787e-03,
#           1.4540165e-02, -2.3057328e-04,  5.7374925e-04, -4.4719800e-03,
#           7.4066536e-04,  3.7779473e-03, -3.8859823e-03,  4.9095595e-04,
#          -2.1161817e-03,  2.8709704e-03,  1.2292061e-03, -3.6375460e-03,
# ...

# %%
npyfile.item().keys()
# Out:
# [u'cccp1',
#  u'cccp2',
#  u'cccp3',
#  u'cccp4',
#  u'cccp5',
#  u'conv3',
#  u'ip2',
#  u'conv2',
#  u'conv1',
#  u'ip1']

# %%
npyfile.item()['cccp1']
# Out:
# {'biases': array([-1.6400156e-03, -6.2719160e-03,  1.2537261e-02,  2.4495109e-03,
#          1.6512135e-03,  7.3912146e-04, -9.9479000e-04,  2.1285659e-03,
#         -1.2881629e-03,  1.0421216e-03, -8.9670736e-03, -1.7095563e-03,
#         -9.8499804e-05,  1.1823236e-02,  2.2818659e-04,  1.6910430e-02,
#          3.4097373e-03, -3.6987257e-03,  9.7461641e-03,  7.1185571e-03,
#         -3.0551711e-03,  1.0060653e-03, -3.3099691e-03, -5.2784877e-03,
#          3.9435732e-03,  1.7037194e-03,  1.4418190e-03, -7.6148979e-05,
#          2.7768440e-03, -6.3481933e-04,  4.3488592e-03,  1.1933401e-03,
#          2.6982729e-03, -7.1052662e-03, -6.6257333e-03, -1.2871380e-04,
#         -3.4047390e-04, -2.5057115e-03,  1.5578649e-02, -2.4019787e-03,
#          1.4540165e-02, -2.3057328e-04,  5.7374925e-04, -4.4719800e-03,
#          7.4066536e-04,  3.7779473e-03, -3.8859823e-03,  4.9095595e-04,
#         -2.1161817e-03,  2.8709704e-03,  1.2292061e-03, -3.6375460e-03,
# ...
